# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Createa  set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size =2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | surab
# Processing Record 2 of Set 1 | forestville
# Processing Record 3 of Set 1 | narsaq
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | huarmey
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | nanortalik
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | harper
# Processing Record 11 of Set 1 | sinnamary
# Processing Record 12 of Set 1 | eidfjord
# Processing Record 13 of Set 1 | gewane
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | axim
# Processing Record 17 of Set 1 | sawakin
# Processing Record 18 of Set 1 | vestmannaeyjar
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | oeiras
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | marzuq
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | quimper
# Processing Record 25 of Set 1 | clyde river
# Processing Record 26 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | olafsvik
# Processing Record 29 of Set 1 | gravdal
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | saldanha
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | torbay
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | itaqui
# Processing Record 36 of Set 1 | whitley bay
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | puerto rico
# Processing Record 40 of Set 1 | necochea
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | riyadh
# Processing Record 43 of Set 1 | makhalino
# Processing Record 44 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 45 of Set 1 | nantucket
# Processing Record 46 of Set 1 | faya
# Processing Record 47 of Set 1 | sarkand
# Processing Record 48 of Set 1 | buenos aires
# Processing Record 49 of Set 1 | saint-augustin
# Processing Record 50 of Set 1 | shar
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | puri
# Processing Record 3 of Set 2 | acari
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | hare bay
# Processing Record 6 of Set 2 | nizwa
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | farafangana
# Processing Record 11 of Set 2 | vila velha
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | hamilton
# Processing Record 14 of Set 2 | sumbe
# Processing Record 15 of Set 2 | hazebrouck
# Processing Record 16 of Set 2 | jodhpur
# Processing Record 17 of Set 2 | mantena
# Processing Record 18 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | nioro
# Processing Record 21 of Set 2 | krasnoshchekovo
# Processing Record 22 of Set 2 | liverpool
# Processing Record 23 of Set 2 | sao joao da barra
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | zhezkazgan
# Processing Record 26 of Set 2 | otjimbingwe
# Processing Record 27 of Set 2 | andenes
# Processing Record 28 of Set 2 | chirilagua
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | arinos
# Processing Record 31 of Set 2 | kontagora
# Processing Record 32 of Set 2 | tucuman
# Processing Record 33 of Set 2 | carhuaz
# Processing Record 34 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 2 | monrovia
# Processing Record 36 of Set 2 | senanga
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | bilma
# Processing Record 39 of Set 2 | marawi
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | sept-iles
# Processing Record 42 of Set 2 | presidencia roque saenz pena
# Processing Record 43 of Set 2 | bandarbeyla
# Processing Record 44 of Set 2 | shu
# Processing Record 45 of Set 2 | agirish
# Processing Record 46 of Set 2 | luderitz
# Processing Record 47 of Set 2 | buraydah
# Processing Record 48 of Set 2 | rovaniemi
# Processing Record 49 of Set 2 | gazanjyk
# Processing Record 50 of Set 2 | dmanisi
# Processing Record 1 of Set 3 | ambo
# Processing Record 2 of Set 3 | korla
# Processing Record 3 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 3 | muzaffarabad
# Processing Record 5 of Set 3 | ghanzi
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | bambous virieux
# Processing Record 8 of Set 3 | viedma
# Processing Record 9 of Set 3 | isiro
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | saint anthony
# Processing Record 13 of Set 3 | sao filipe
# Processing Record 14 of Set 3 | los llanos de aridane
# Processing Record 15 of Set 3 | murmino
# Processing Record 16 of Set 3 | klaksvik
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | nobres
# Processing Record 19 of Set 3 | nicoya
# Processing Record 20 of Set 3 | nouadhibou
# Processing Record 21 of Set 3 | anloga
# Processing Record 22 of Set 3 | saint-pierre
# Processing Record 23 of Set 3 | raduzhnyy
# Processing Record 24 of Set 3 | tallahassee
# Processing Record 25 of Set 3 | san rafael
# Processing Record 26 of Set 3 | kamina
# Processing Record 27 of Set 3 | cockburn town
# Processing Record 28 of Set 3 | yaritagua
# Processing Record 29 of Set 3 | kralendijk
# Processing Record 30 of Set 3 | butembo
# Processing Record 31 of Set 3 | akureyri
# Processing Record 32 of Set 3 | coracora
# Processing Record 33 of Set 3 | beloha
# Processing Record 34 of Set 3 | maniitsoq
# Processing Record 35 of Set 3 | taguatinga
# Processing Record 36 of Set 3 | belmonte
# Processing Record 37 of Set 3 | kavaratti
# Processing Record 38 of Set 3 | sao jose do belmonte
# Processing Record 39 of Set 3 | aksarka
# Processing Record 40 of Set 3 | santona
# Processing Record 41 of Set 3 | jalu
# Processing Record 42 of Set 3 | richards bay
# Processing Record 43 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 3 | felipe carrillo puerto
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | soyo
# Processing Record 47 of Set 3 | ajdabiya
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | cabo rojo
# Processing Record 50 of Set 3 | calabozo
# Processing Record 1 of Set 4 | kulhudhuffushi
# Processing Record 2 of Set 4 | kudahuvadhoo
# Processing Record 3 of Set 4 | henties bay
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | puerto del rosario
# Processing Record 6 of Set 4 | rondonopolis
# Processing Record 7 of Set 4 | presidente prudente
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | laguna
# Processing Record 10 of Set 4 | caravelas
# Processing Record 11 of Set 4 | husavik
# Processing Record 12 of Set 4 | micomeseng
# Processing Record 13 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 14 of Set 4 | boueni
# Processing Record 15 of Set 4 | thinadhoo
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | raudeberg
# Processing Record 18 of Set 4 | souillac
# Processing Record 19 of Set 4 | berlevag
# Processing Record 20 of Set 4 | ostrovnoy
# Processing Record 21 of Set 4 | touros
# Processing Record 22 of Set 4 | tambura
# Processing Record 23 of Set 4 | sao luis do quitunde
# Processing Record 24 of Set 4 | bongandanga
# Processing Record 25 of Set 4 | paysandu
# Processing Record 26 of Set 4 | atar
# Processing Record 27 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 4 | jizan
# Processing Record 29 of Set 4 | cuamba
# Processing Record 30 of Set 4 | mogadishu
# Processing Record 31 of Set 4 | bismil
# Processing Record 32 of Set 4 | vila franca do campo
# Processing Record 33 of Set 4 | rusape
# Processing Record 34 of Set 4 | roald
# Processing Record 35 of Set 4 | sao miguel
# Processing Record 36 of Set 4 | abha
# Processing Record 37 of Set 4 | odweyne
# Processing Record 38 of Set 4 | rio brilhante
# Processing Record 39 of Set 4 | blagoyevo
# Processing Record 40 of Set 4 | mwense
# Processing Record 41 of Set 4 | abu kamal
# Processing Record 42 of Set 4 | olinda
# Processing Record 43 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 4 | sayyan
# Processing Record 45 of Set 4 | lima
# Processing Record 46 of Set 4 | annau
# Processing Record 47 of Set 4 | falmouth
# Processing Record 48 of Set 4 | port hawkesbury
# Processing Record 49 of Set 4 | constanta
# Processing Record 50 of Set 4 | veraval
# Processing Record 1 of Set 5 | antalaha
# Processing Record 2 of Set 5 | lyuban
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | kruisfontein
# Processing Record 5 of Set 5 | losal
# Processing Record 6 of Set 5 | niksar
# Processing Record 7 of Set 5 | jeremie
# Processing Record 8 of Set 5 | santa flavia
# Processing Record 9 of Set 5 | peniche
# Processing Record 10 of Set 5 | mayumba
# Processing Record 11 of Set 5 | san cristobal
# Processing Record 12 of Set 5 | kosh-agach
# Processing Record 13 of Set 5 | loum
# Processing Record 14 of Set 5 | leh
# Processing Record 15 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 5 | winsum
# Processing Record 17 of Set 5 | bredasdorp
# Processing Record 18 of Set 5 | chateauroux
# Processing Record 19 of Set 5 | fredericton
# Processing Record 20 of Set 5 | puerto narino
# Processing Record 21 of Set 5 | umm kaddadah
# Processing Record 22 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 5 | wilmington
# Processing Record 24 of Set 5 | santa rosa
# Processing Record 25 of Set 5 | barao de melgaco
# Processing Record 26 of Set 5 | la montanita
# Processing Record 27 of Set 5 | muli
# Processing Record 28 of Set 5 | puerto quijarro
# Processing Record 29 of Set 5 | praia da vitoria
# Processing Record 30 of Set 5 | maues
# Processing Record 31 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 5 | belchatow
# Processing Record 33 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 5 | panormos
# Processing Record 35 of Set 5 | mumford
# Processing Record 36 of Set 5 | namibe
# Processing Record 37 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 38 of Set 5 | sao felix do xingu
# Processing Record 39 of Set 5 | shirdi
# Processing Record 40 of Set 5 | hargeysa
# Processing Record 41 of Set 5 | ustyuzhna
# Processing Record 42 of Set 5 | varhaug
# Processing Record 43 of Set 5 | sudzha
# Processing Record 44 of Set 5 | zabol
# Processing Record 45 of Set 5 | bathsheba
# Processing Record 46 of Set 5 | tocopilla
# Processing Record 47 of Set 5 | mahibadhoo
# Processing Record 48 of Set 5 | george town
# Processing Record 49 of Set 5 | rio gallegos
# Processing Record 50 of Set 5 | nuuk
# Processing Record 1 of Set 6 | san ramon de la nueva oran
# Processing Record 2 of Set 6 | jardim
# Processing Record 3 of Set 6 | suez
# Processing Record 4 of Set 6 | arbazh
# Processing Record 5 of Set 6 | taltal
# Processing Record 6 of Set 6 | ferme-neuve
# Processing Record 7 of Set 6 | adrar
# Processing Record 8 of Set 6 | mulchen
# Processing Record 9 of Set 6 | clonakilty
# Processing Record 10 of Set 6 | aksarayskiy
# Processing Record 11 of Set 6 | shahr-e babak
# Processing Record 12 of Set 6 | bayburt
# Processing Record 13 of Set 6 | saquarema
# Processing Record 14 of Set 6 | vardo
# Processing Record 15 of Set 6 | stromness
# Processing Record 16 of Set 6 | tonj
# Processing Record 17 of Set 6 | maraa
# Processing Record 18 of Set 6 | vagur
# Processing Record 19 of Set 6 | itarema
# Processing Record 20 of Set 6 | bahia honda
# Processing Record 21 of Set 6 | imbituva
# Processing Record 22 of Set 6 | hobyo
# Processing Record 23 of Set 6 | rocha
# Processing Record 24 of Set 6 | mattawa
# Processing Record 25 of Set 6 | muyezerskiy
# Processing Record 26 of Set 6 | codrington
# Processing Record 27 of Set 6 | saint-ambroise
# Processing Record 28 of Set 6 | hohr-grenzhausen
# Processing Record 29 of Set 6 | balkanabat
# Processing Record 30 of Set 6 | dulce nombre de culmi
# Processing Record 31 of Set 6 | bronnoysund
# Processing Record 32 of Set 6 | ponta delgada
# Processing Record 33 of Set 6 | bereda
# Processing Record 34 of Set 6 | mahon
# Processing Record 35 of Set 6 | rio grande
# Processing Record 36 of Set 6 | chilca
# Processing Record 37 of Set 6 | murillo
# Processing Record 38 of Set 6 | gadsden
# Processing Record 39 of Set 6 | gunjur
# Processing Record 40 of Set 6 | sargatskoye
# Processing Record 41 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 6 | illela
# Processing Record 43 of Set 6 | praia
# Processing Record 44 of Set 6 | algiers
# Processing Record 45 of Set 6 | terrace bay
# Processing Record 46 of Set 6 | kanniyakumari
# Processing Record 47 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 48 of Set 6 | krasnotorka
# Processing Record 49 of Set 6 | margate
# Processing Record 50 of Set 6 | lasa
# Processing Record 1 of Set 7 | shiggaon
# Processing Record 2 of Set 7 | gandai
# Processing Record 3 of Set 7 | rawson
# Processing Record 4 of Set 7 | muros
# Processing Record 5 of Set 7 | qarayeri
# Processing Record 6 of Set 7 | mehamn
# Processing Record 7 of Set 7 | ginda
# Processing Record 8 of Set 7 | kumluca
# Processing Record 9 of Set 7 | seydi
# Processing Record 10 of Set 7 | pervomaysk
# Processing Record 11 of Set 7 | rio branco do sul
# Processing Record 12 of Set 7 | pisco
# Processing Record 13 of Set 7 | bonito
# Processing Record 14 of Set 7 | yekaterinovka
# Processing Record 15 of Set 7 | aksu
# Processing Record 16 of Set 7 | san joaquin
# Processing Record 17 of Set 7 | savannah bight
# Processing Record 18 of Set 7 | matara
# Processing Record 19 of Set 7 | shahrud
# Processing Record 20 of Set 7 | shetpe
# Processing Record 21 of Set 7 | rosario do sul
# Processing Record 22 of Set 7 | sistranda
# Processing Record 23 of Set 7 | umarkot
# Processing Record 24 of Set 7 | nezhinka
# Processing Record 25 of Set 7 | vikulovo
# Processing Record 26 of Set 7 | belleville
# Processing Record 27 of Set 7 | muisne
# Processing Record 28 of Set 7 | gobindpur
# Processing Record 29 of Set 7 | awjilah
# Processing Record 30 of Set 7 | proletarskiy
# Processing Record 31 of Set 7 | zambezi
# Processing Record 32 of Set 7 | thompson
# Processing Record 33 of Set 7 | gayny
# Processing Record 34 of Set 7 | kant
# Processing Record 35 of Set 7 | itaberaba
# Processing Record 36 of Set 7 | kalmunai
# Processing Record 37 of Set 7 | grindavik
# Processing Record 38 of Set 7 | diffa
# Processing Record 39 of Set 7 | yugorsk
# Processing Record 40 of Set 7 | parana
# Processing Record 41 of Set 7 | maku
# Processing Record 42 of Set 7 | kochi
# Processing Record 43 of Set 7 | santa cruz
# Processing Record 44 of Set 7 | killybegs
# Processing Record 45 of Set 7 | chadiza
# Processing Record 46 of Set 7 | mangan
# Processing Record 47 of Set 7 | dolores
# Processing Record 48 of Set 7 | belogradcik
# City not found. Skipping...
# Processing Record 49 of Set 7 | cidreira
# Processing Record 50 of Set 7 | hofn
# Processing Record 1 of Set 8 | natal
# Processing Record 2 of Set 8 | gat
# Processing Record 3 of Set 8 | carnarvon
# Processing Record 4 of Set 8 | farap
# Processing Record 5 of Set 8 | nurota
# Processing Record 6 of Set 8 | ville-marie
# Processing Record 7 of Set 8 | yalutorovsk
# Processing Record 8 of Set 8 | yar-sale
# Processing Record 9 of Set 8 | dongobesh
# Processing Record 10 of Set 8 | velyka pysarivka
# Processing Record 11 of Set 8 | lokhvytsya
# Processing Record 12 of Set 8 | domoni
# Processing Record 13 of Set 8 | cubuk
# Processing Record 14 of Set 8 | virginia beach
# Processing Record 15 of Set 8 | nalut
# Processing Record 16 of Set 8 | mitsamiouli
# Processing Record 17 of Set 8 | sanchursk
# Processing Record 18 of Set 8 | chicama
# Processing Record 19 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 8 | urfa
# City not found. Skipping...
# Processing Record 21 of Set 8 | sorland
# Processing Record 22 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 8 | skjervoy
# Processing Record 26 of Set 8 | hauterive
# Processing Record 27 of Set 8 | zaranj
# Processing Record 28 of Set 8 | ust-koksa
# Processing Record 29 of Set 8 | havelock
# Processing Record 30 of Set 8 | garm
# City not found. Skipping...
# Processing Record 31 of Set 8 | methoni
# Processing Record 32 of Set 8 | vangaindrano
# Processing Record 33 of Set 8 | maldonado
# Processing Record 34 of Set 8 | ribas do rio pardo
# Processing Record 35 of Set 8 | tottenham
# Processing Record 36 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 8 | kandry
# Processing Record 38 of Set 8 | jaciara
# Processing Record 39 of Set 8 | natitingou
# Processing Record 40 of Set 8 | tahoua
# Processing Record 41 of Set 8 | salalah
# Processing Record 42 of Set 8 | pangnirtung
# Processing Record 43 of Set 8 | neyvo-shaytanskiy
# Processing Record 44 of Set 8 | elati
# Processing Record 45 of Set 8 | qandala
# Processing Record 46 of Set 8 | somerset
# Processing Record 47 of Set 8 | areia branca
# Processing Record 48 of Set 8 | khash
# Processing Record 49 of Set 8 | aripuana
# Processing Record 50 of Set 8 | yuzhno-sukhokumsk
# Processing Record 1 of Set 9 | bosobolo
# Processing Record 2 of Set 9 | chimoio
# Processing Record 3 of Set 9 | aden
# Processing Record 4 of Set 9 | kollam
# Processing Record 5 of Set 9 | kipushi
# Processing Record 6 of Set 9 | dobryatino
# Processing Record 7 of Set 9 | miquelon
# Processing Record 8 of Set 9 | opuwo
# Processing Record 9 of Set 9 | mount pleasant
# Processing Record 10 of Set 9 | zorritos
# Processing Record 11 of Set 9 | sisimiut
# Processing Record 12 of Set 9 | akdepe
# Processing Record 13 of Set 9 | barra patuca
# Processing Record 14 of Set 9 | angra
# City not found. Skipping...
# Processing Record 15 of Set 9 | castro
# Processing Record 16 of Set 9 | el tigre
# Processing Record 17 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 18 of Set 9 | port blair
# Processing Record 19 of Set 9 | pointe-noire
# Processing Record 20 of Set 9 | pemba
# Processing Record 21 of Set 9 | charlestown
# Processing Record 22 of Set 9 | goderich
# Processing Record 23 of Set 9 | talara
# Processing Record 24 of Set 9 | skibbereen
# Processing Record 25 of Set 9 | sibut
# Processing Record 26 of Set 9 | vazante
# Processing Record 27 of Set 9 | dingle
# Processing Record 28 of Set 9 | coquimbo
# Processing Record 29 of Set 9 | solvychegodsk
# Processing Record 30 of Set 9 | megion
# Processing Record 31 of Set 9 | nepa nagar
# Processing Record 32 of Set 9 | ouesso
# Processing Record 33 of Set 9 | lisakovsk
# Processing Record 34 of Set 9 | ombessa
# Processing Record 35 of Set 9 | lethem
# Processing Record 36 of Set 9 | quelimane
# Processing Record 37 of Set 9 | qaqortoq
# Processing Record 38 of Set 9 | the valley
# Processing Record 39 of Set 9 | saint-louis
# Processing Record 40 of Set 9 | yaya
# Processing Record 41 of Set 9 | yarim
# Processing Record 42 of Set 9 | antanifotsy
# Processing Record 43 of Set 9 | tabas
# Processing Record 44 of Set 9 | quatre cocos
# Processing Record 45 of Set 9 | binga
# Processing Record 46 of Set 9 | florianopolis
# Processing Record 47 of Set 9 | mitu
# Processing Record 48 of Set 9 | puerto leguizamo
# Processing Record 49 of Set 9 | maragogi
# Processing Record 50 of Set 9 | notse
# Processing Record 1 of Set 10 | urucara
# Processing Record 2 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 10 | muravlenko
# Processing Record 4 of Set 10 | renukut
# Processing Record 5 of Set 10 | hambantota
# Processing Record 6 of Set 10 | risor
# Processing Record 7 of Set 10 | dondo
# Processing Record 8 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 10 | ciudad bolivar
# Processing Record 10 of Set 10 | kabo
# Processing Record 11 of Set 10 | atuntaqui
# Processing Record 12 of Set 10 | berezniki
# Processing Record 13 of Set 10 | aranos
# Processing Record 14 of Set 10 | shelburne
# Processing Record 15 of Set 10 | mantua
# Processing Record 16 of Set 10 | mega
# Processing Record 17 of Set 10 | ilhabela
# Processing Record 18 of Set 10 | westport
# Processing Record 19 of Set 10 | sao raimundo das mangabeiras
# Processing Record 20 of Set 10 | skelleftea
# Processing Record 21 of Set 10 | kautokeino
# Processing Record 22 of Set 10 | gorgan
# Processing Record 23 of Set 10 | srivardhan
# Processing Record 24 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 10 | grand-santi
# Processing Record 26 of Set 10 | kangaatsiaq
# Processing Record 27 of Set 10 | jibuti
# Processing Record 28 of Set 10 | zhob
# Processing Record 29 of Set 10 | perehonivka
# Processing Record 30 of Set 10 | valparaiso
# Processing Record 31 of Set 10 | havre-saint-pierre
# Processing Record 32 of Set 10 | hvolsvollur
# Processing Record 33 of Set 10 | beyneu
# Processing Record 34 of Set 10 | medea
# Processing Record 35 of Set 10 | canutama
# Processing Record 36 of Set 10 | nchelenge
# Processing Record 37 of Set 10 | kilindoni
# Processing Record 38 of Set 10 | umuarama
# Processing Record 39 of Set 10 | prijepolje
# Processing Record 40 of Set 10 | rocky mount
# Processing Record 41 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 10 | leo
# Processing Record 43 of Set 10 | irece
# Processing Record 44 of Set 10 | arya
# Processing Record 45 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 46 of Set 10 | tete
# Processing Record 47 of Set 10 | bosaso
# Processing Record 48 of Set 10 | cap malheureux
# Processing Record 49 of Set 10 | ouadda
# Processing Record 50 of Set 10 | santa cruz cabralia
# Processing Record 1 of Set 11 | yarada
# Processing Record 2 of Set 11 | sernur
# Processing Record 3 of Set 11 | santa isabel do rio negro
# Processing Record 4 of Set 11 | kalabo
# Processing Record 5 of Set 11 | alegrete
# Processing Record 6 of Set 11 | spring hill
# Processing Record 7 of Set 11 | morant bay
# Processing Record 8 of Set 11 | cerro azul
# Processing Record 9 of Set 11 | bubaque
# Processing Record 10 of Set 11 | libreville
# Processing Record 11 of Set 11 | kolpashevo
# Processing Record 12 of Set 11 | aguimes
# Processing Record 13 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 14 of Set 11 | saint-georges
# Processing Record 15 of Set 11 | mezinovskiy
# Processing Record 16 of Set 11 | cayenne
# Processing Record 17 of Set 11 | manoel urbano
# Processing Record 18 of Set 11 | tripoli
# Processing Record 19 of Set 11 | turukhansk
# Processing Record 20 of Set 11 | camocim
# Processing Record 21 of Set 11 | thanesar
# Processing Record 22 of Set 11 | liniere
# City not found. Skipping...
# Processing Record 23 of Set 11 | segou
# Processing Record 24 of Set 11 | elista
# Processing Record 25 of Set 11 | uruzgan
# Processing Record 26 of Set 11 | umm lajj
# Processing Record 27 of Set 11 | loanda
# Processing Record 28 of Set 11 | akcakoca
# Processing Record 29 of Set 11 | nevsehir
# Processing Record 30 of Set 11 | kushmurun
# Processing Record 31 of Set 11 | eidsvag
# Processing Record 32 of Set 11 | lieksa
# Processing Record 33 of Set 11 | linda
# Processing Record 34 of Set 11 | robertsport
# Processing Record 35 of Set 11 | starozhilovo
# Processing Record 36 of Set 11 | abapo
# Processing Record 37 of Set 11 | mokolo
# Processing Record 38 of Set 11 | haywards heath
# Processing Record 39 of Set 11 | ornskoldsvik
# Processing Record 40 of Set 11 | bondoukou
# Processing Record 41 of Set 11 | kisangani
# Processing Record 42 of Set 11 | tarumovka
# Processing Record 43 of Set 11 | naryan-mar
# Processing Record 44 of Set 11 | ailigandi
# Processing Record 45 of Set 11 | neder vindinge
# Processing Record 46 of Set 11 | grand gaube
# Processing Record 47 of Set 11 | san pedro del parana
# Processing Record 48 of Set 11 | bom jesus
# Processing Record 49 of Set 11 | ibipeba
# Processing Record 50 of Set 11 | ostrovskoye
# Processing Record 1 of Set 12 | biltine
# Processing Record 2 of Set 12 | elat
# Processing Record 3 of Set 12 | bengkulu
# Processing Record 4 of Set 12 | cerro de pasco
# Processing Record 5 of Set 12 | weligama
# Processing Record 6 of Set 12 | puerto plata
# Processing Record 7 of Set 12 | kaoma
# Processing Record 8 of Set 12 | hauknes
# Processing Record 9 of Set 12 | howard
# Processing Record 10 of Set 12 | walvis bay
# Processing Record 11 of Set 12 | varnavino
# Processing Record 12 of Set 12 | talnakh
# Processing Record 13 of Set 12 | lubao
# Processing Record 14 of Set 12 | matagami
# Processing Record 15 of Set 12 | nouakchott
# Processing Record 16 of Set 12 | zuwarah
# Processing Record 17 of Set 12 | pimentel
# Processing Record 18 of Set 12 | hudiksvall
# Processing Record 19 of Set 12 | asilah
# Processing Record 20 of Set 12 | houma
# Processing Record 21 of Set 12 | morondava
# Processing Record 22 of Set 12 | requena
# Processing Record 23 of Set 12 | jamame
# Processing Record 24 of Set 12 | aswan
# Processing Record 25 of Set 12 | marystown
# Processing Record 26 of Set 12 | asfi
# Processing Record 27 of Set 12 | minsk
# Processing Record 28 of Set 12 | mecca
# Processing Record 29 of Set 12 | locri
# Processing Record 30 of Set 12 | anzio
# Processing Record 31 of Set 12 | guane
# Processing Record 32 of Set 12 | igrim
# Processing Record 33 of Set 12 | bonthe
# Processing Record 34 of Set 12 | timmins
# Processing Record 35 of Set 12 | junin
# Processing Record 36 of Set 12 | kayes
# Processing Record 37 of Set 12 | amapa
# Processing Record 38 of Set 12 | porto novo
# Processing Record 39 of Set 12 | malakal
# Processing Record 40 of Set 12 | tabou
# Processing Record 41 of Set 12 | lokosovo
# Processing Record 42 of Set 12 | mana
# Processing Record 43 of Set 12 | porbandar
# Processing Record 44 of Set 12 | mirabad
# Processing Record 45 of Set 12 | dutse
# Processing Record 46 of Set 12 | sankt veit
# Processing Record 47 of Set 12 | sananduva
# Processing Record 48 of Set 12 | ambovombe
# Processing Record 49 of Set 12 | malkangiri
# Processing Record 50 of Set 12 | chipoka
# Processing Record 1 of Set 13 | menongue
# Processing Record 2 of Set 13 | talsi
# Processing Record 3 of Set 13 | malanje
# Processing Record 4 of Set 13 | hammerfest
# Processing Record 5 of Set 13 | mudanya
# Processing Record 6 of Set 13 | sharanga
# Processing Record 7 of Set 13 | kirkland lake
# Processing Record 8 of Set 13 | kremenki
# Processing Record 9 of Set 13 | selma
# Processing Record 10 of Set 13 | marfino
# Processing Record 11 of Set 13 | saint-esteve
# Processing Record 12 of Set 13 | hryshkivtsi
# Processing Record 13 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 14 of Set 13 | bafq
# Processing Record 15 of Set 13 | vila do maio
# Processing Record 16 of Set 13 | paamiut
# Processing Record 17 of Set 13 | igunga
# Processing Record 18 of Set 13 | ardabil
# Processing Record 19 of Set 13 | tingrela
# City not found. Skipping...
# Processing Record 20 of Set 13 | padang
# Processing Record 21 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 13 | duz
# City not found. Skipping...
# Processing Record 23 of Set 13 | coihaique
# Processing Record 24 of Set 13 | reconquista
# Processing Record 25 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 13 | gondar
# Processing Record 27 of Set 13 | bolotnoye
# Processing Record 28 of Set 13 | callaway
# Processing Record 29 of Set 13 | tornio
# Processing Record 30 of Set 13 | plettenberg bay
# Processing Record 31 of Set 13 | kandri
# Processing Record 32 of Set 13 | geilo
# Processing Record 33 of Set 13 | maceio
# Processing Record 34 of Set 13 | puerto carreno
# Processing Record 35 of Set 13 | harnosand
# Processing Record 36 of Set 13 | butia
# Processing Record 37 of Set 13 | prudentopolis
# Processing Record 38 of Set 13 | somerset east
# Processing Record 39 of Set 13 | oksfjord
# Processing Record 40 of Set 13 | strezhevoy
# Processing Record 41 of Set 13 | inhambane
# Processing Record 42 of Set 13 | oranjemund
# Processing Record 43 of Set 13 | uvat
# Processing Record 44 of Set 13 | vieux-habitants
# Processing Record 45 of Set 13 | dareda
# Processing Record 46 of Set 13 | pozo colorado
# Processing Record 47 of Set 13 | mani
# Processing Record 48 of Set 13 | bensonville
# Processing Record 49 of Set 13 | bajil
# Processing Record 50 of Set 13 | inongo
# Processing Record 1 of Set 14 | guca
# Processing Record 2 of Set 14 | bud
# Processing Record 3 of Set 14 | sur
# Processing Record 4 of Set 14 | raga
# Processing Record 5 of Set 14 | saint-joseph
# Processing Record 6 of Set 14 | ilebo
# Processing Record 7 of Set 14 | general roca
# Processing Record 8 of Set 14 | correntina
# Processing Record 9 of Set 14 | ler
# Processing Record 10 of Set 14 | athy
# Processing Record 11 of Set 14 | haftoni
# Processing Record 12 of Set 14 | rorvik
# Processing Record 13 of Set 14 | kamenka
# Processing Record 14 of Set 14 | le port
# Processing Record 15 of Set 14 | parrita
# Processing Record 16 of Set 14 | kislovodsk
# Processing Record 17 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 19 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 14 | vestmanna
# Processing Record 21 of Set 14 | angoche
# Processing Record 22 of Set 14 | lucapa
# Processing Record 23 of Set 14 | taunsa
# Processing Record 24 of Set 14 | mahanoro
# Processing Record 25 of Set 14 | golden gate
# Processing Record 26 of Set 14 | johnson city
# Processing Record 27 of Set 14 | neyshabur
# Processing Record 28 of Set 14 | rotterdam
# Processing Record 29 of Set 14 | burica
# City not found. Skipping...
# Processing Record 30 of Set 14 | eenhana
# Processing Record 31 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 32 of Set 14 | sokyryany
# Processing Record 33 of Set 14 | changji
# Processing Record 34 of Set 14 | dwarka
# Processing Record 35 of Set 14 | muhororo
# Processing Record 36 of Set 14 | coronel
# Processing Record 37 of Set 14 | kuytun
# Processing Record 38 of Set 14 | clarence town
# Processing Record 39 of Set 14 | mahajanga
# Processing Record 40 of Set 14 | immokalee
# Processing Record 41 of Set 14 | oistins
# Processing Record 42 of Set 14 | miraflores
# Processing Record 43 of Set 14 | asosa
# Processing Record 44 of Set 14 | la asuncion
# Processing Record 45 of Set 14 | nagua
# Processing Record 46 of Set 14 | mustvee
# Processing Record 47 of Set 14 | isla mujeres
# Processing Record 48 of Set 14 | muzhi
# Processing Record 49 of Set 14 | nueva helvecia
# Processing Record 50 of Set 14 | bela
# Processing Record 1 of Set 15 | tukrah
# Processing Record 2 of Set 15 | englewood
# Processing Record 3 of Set 15 | lovozero
# Processing Record 4 of Set 15 | saint-francois
# Processing Record 5 of Set 15 | tucurui
# Processing Record 6 of Set 15 | javanrud
# Processing Record 7 of Set 15 | pitimbu
# Processing Record 8 of Set 15 | addi ugri
# City not found. Skipping...
# Processing Record 9 of Set 15 | findlay
# Processing Record 10 of Set 15 | oussouye
# Processing Record 11 of Set 15 | goba
# Processing Record 12 of Set 15 | loiza
# Processing Record 13 of Set 15 | biskamzha
# Processing Record 14 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 15 of Set 15 | buzmeyin
# Processing Record 16 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 17 of Set 15 | remontnoye
# Processing Record 18 of Set 15 | alta floresta
# Processing Record 19 of Set 15 | opobo
# City not found. Skipping...
# Processing Record 20 of Set 15 | tiffin
# Processing Record 21 of Set 15 | kinshasa
# Processing Record 22 of Set 15 | port shepstone
# Processing Record 23 of Set 15 | trincomalee
# Processing Record 24 of Set 15 | nizhnyaya tavda
# Processing Record 25 of Set 15 | buta
# Processing Record 26 of Set 15 | boa vista
# Processing Record 27 of Set 15 | ivdel
# Processing Record 28 of Set 15 | paragominas
# Processing Record 29 of Set 15 | qiryat gat
# Processing Record 30 of Set 15 | sidhi
# Processing Record 31 of Set 15 | kuybysheve
# Processing Record 32 of Set 15 | eyl
# Processing Record 33 of Set 15 | srikakulam
# Processing Record 34 of Set 15 | hirtshals
# Processing Record 35 of Set 15 | balaghat
# Processing Record 36 of Set 15 | okitipupa
# Processing Record 37 of Set 15 | pokhara
# Processing Record 38 of Set 15 | pestovo
# Processing Record 39 of Set 15 | dossor
# Processing Record 40 of Set 15 | imbituba
# Processing Record 41 of Set 15 | sangmelima
# Processing Record 42 of Set 15 | kanashevo
# Processing Record 43 of Set 15 | zamora
# Processing Record 44 of Set 15 | buchanan
# Processing Record 45 of Set 15 | rabo de peixe
# Processing Record 46 of Set 15 | oxford
# Processing Record 47 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 48 of Set 15 | chapais
# Processing Record 49 of Set 15 | teramo
# Processing Record 50 of Set 15 | obo
# Processing Record 1 of Set 16 | san antonio
# Processing Record 2 of Set 16 | bari sadri
# Processing Record 3 of Set 16 | arona
# Processing Record 4 of Set 16 | tyup
# Processing Record 5 of Set 16 | katete
# Processing Record 6 of Set 16 | marrakesh
# Processing Record 7 of Set 16 | iznik
# Processing Record 8 of Set 16 | nivala
# Processing Record 9 of Set 16 | mahadday weyne
# City not found. Skipping...
# Processing Record 10 of Set 16 | mandal
# Processing Record 11 of Set 16 | constitucion
# Processing Record 12 of Set 16 | bethanien
# Processing Record 13 of Set 16 | carutapera
# Processing Record 14 of Set 16 | tiznit
# Processing Record 15 of Set 16 | san javier
# Processing Record 16 of Set 16 | remanso
# Processing Record 17 of Set 16 | linhares
# Processing Record 18 of Set 16 | san andres
# Processing Record 19 of Set 16 | poltavka
# Processing Record 20 of Set 16 | sinkat
# City not found. Skipping...
# Processing Record 21 of Set 16 | dedza
# Processing Record 22 of Set 16 | los chiles
# Processing Record 23 of Set 16 | honningsvag
# Processing Record 24 of Set 16 | mangrol
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Surab  28.4914  66.2585     93.99         2           0       18.63
# 1  Forestville  38.8451 -76.8750     71.49        81           1        1.01
# 2       Narsaq  60.9167 -46.0500     40.23        75          79        3.51
# 3  East London -33.0153  27.9116     70.74        60           0        4.61
# 4      Huarmey -10.0681 -78.1522     65.14        86          16        2.13
#
#   Current Description Country                 Date
# 0           clear sky      PK  2021-06-14 11:57:31
# 1           clear sky      US  2021-06-14 11:57:31
# 2       broken clouds      GL  2021-06-14 11:56:07
# 3           clear sky      ZA  2021-06-14 11:54:33
# 4          few clouds      PE  2021-06-14 11:54:33

# %%
# Reorder columns
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Surab      PK  28.4914  66.2585     93.99         2           0
# 1  Forestville      US  38.8451 -76.8750     71.49        81           1
# 2       Narsaq      GL  60.9167 -46.0500     40.23        75          79
# 3  East London      ZA -33.0153  27.9116     70.74        60           0
# 4      Huarmey      PE -10.0681 -78.1522     65.14        86          16
#
#    Wind Speed Current Description
# 0       18.63           clear sky
# 1        1.01           clear sky
# 2        3.51       broken clouds
# 3        4.61           clear sky
# 4        2.13          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
